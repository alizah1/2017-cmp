# %%
# Houman Alizadeh
# Homework Lecture 14
# Brownian motion visualized
import numpy as np
import matplotlib.pyplot as plt

N = 1000
x_axis = 101
y_axis = 101
start = np.empty([N,2])
start[0,0] = int(L1/2)
start[0,1] = int(L2/2)
DoF = np.array([[0,1],[0,-1],[1,0],[-1,0]]) # DoF = Degree of Freedom
for i in range(1,N):
    Initial = [-1,-1]
    while min(Initial)<0 or Initial[0] > x_axis or Initial[1] > y_axis:
        Motion = np.random.randint(len(DoF))
        Initial = start[i-1,:] + DoF[Motion]
        
    start[i,:] = Initial
plt.xlim(0,101)
plt.ylim(0,101)
plt.title('Brownian motion of a particle')
plt.plot(start[:,0], start[:,1], '--')        
plt.show()

# %%
# Radioactive Decay with 1000 random numbers
import numpy as np
import matplotlib.pyplot as plt

tau = 3.053*60
N=1000
P = np.log(2)/tau
N_Tl=1000
tmax=1000

Distribution = []
Tl = N_Tl * np.ones([tmax-1])
Pb = np.zeros([tmax-1])

for i in range(N_Tl):
    Random = np.random.random()
    random_numbers = int(-np.log(1-Random)/P)
    Distribution.append(random_numbers)
    if random_numbers < tmax:
        Tl[random_numbers:] -= 1
        Pb[random_numbers:] += 1
        
        
        
plt.plot(Tl, label='Tl' , color='red')
plt.plot(Pb, label='Pb', color='blue')
plt.title('Decay of Tl & Pb')
plt.xlabel("Time (s)")
plt.ylabel("Number of atoms")

plt.legend()
plt.show()

plt.hist(Distribution)
plt.title('The Distribution of Random Numbers')
plt.xlim(0,1000)
plt.ylim(0,1000)
plt.show()
