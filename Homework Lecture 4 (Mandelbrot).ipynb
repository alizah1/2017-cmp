# %%
# Houman Alizadeh
# Homework lecture 4
import numpy as np
import matplotlib.pyplot as plt
def Mandelbrot_Function(a, bi, number_of_iterations):
# The Mandelbrot function is made up of complex numbers a = real number , bi = imaginary number 
   # some functions like "complex" are already built in python
    c = complex(a, bi)

    # I just chose an arbitrary number for z. It won't affect our graph. You can choose any number    
   
    z = 2.0j
    
    for i in range(number_of_iterations):
        z = z*z + c
        # Based on the definition the absolute value of z has to be greater thaan 2
        if (z.real**2 + z.imag**2) >= 2:
            return i
        
    return number_of_iterations
# x defines the number of divisions in the x-axis and y defines the number of divisions in the y-axis
x , y = 800 , 800
P = numpy.zeros([x, y])

for x in range(len(np.linspace(-2, 2, x))):
    
    for y in range(len(np.linspace(-2, 2 , y))):
       
        P[x , y] = Mandelbrot_Function(a, bi, 800)
plt.imshow(result.T, extent=[-2, 2, -2, 2])
# By putting result.T you can actually rotate the graph by 90 degrees   
plt.magma()
plt.xlabel('Real Numbers')
plt.ylabel('Imaginary Numbers')
plt.show()
